# %%
pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\nate\anaconda3\envs\learn-env\lib\site-packages (4.7.2)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\nate\anaconda3\envs\learn-env\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\nate\anaconda3\envs\learn-env\lib\site-packages (from selenium) (2022.12.7)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\nate\anaconda3\envs\learn-env\lib\site-packages (from selenium) (1.26.14)
# Requirement already satisfied: trio~=0.17 in c:\users\nate\anaconda3\envs\learn-env\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: async-generator>=1.10 in c:\users\nate\anaconda3\envs\learn-env\lib\site-packages (from trio-websocket~=0.9->selenium) (1.10)
# Requirement already satisfied: wsproto>=0.14 in c:\users\nate\anaconda3\envs\learn-env\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6; extra == "socks" in c:\users\nate\anaconda3\envs\learn-env\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: cffi>=1.14; os_name == "nt" and implementation_name != "pypy" in c:\users\nate\anaconda3\envs\learn-env\lib\site-packages (from trio~=0.17->selenium) (1.14.3)
# Requirement already satisfied: outcome in c:\users\nate\anaconda3\envs\learn-env\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\nate\anaconda3\envs\learn-env\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\nate\anaconda3\envs\learn-env\lib\site-packages (from trio~=0.17->selenium) (20.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9; python_version < "3.11" in c:\users\nate\anaconda3\envs\learn-env\lib\site-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: idna in c:\users\nate\anaconda3\envs\learn-env\lib\site-packages (from trio~=0.17->selenium) (2.10)
# Requirement already satisfied: sniffio in c:\users\nate\anaconda3\envs\learn-env\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\nate\anaconda3\envs\learn-env\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Requirement already satisfied: pycparser in c:\users\nate\anaconda3\envs\learn-env\lib\site-packages (from cffi>=1.14; os_name == "nt" and implementation_name != "pypy"->trio~=0.17->selenium) (2.20)
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import re

from bs4 import BeautifulSoup
import requests
from urllib.parse import urljoin
import string
import os
import time

# %%
options = Options()
#options.headless = False
#options.add_argument("--window-size=1920,1200")

# This is the primary dictionary with the links of the phases.  We will add to it all the info'
course_info = [
    {'phase_title':'Pre-work', 'phase_link':'https://learning.flatironschool.com/courses/6103'},
]

# %%
def getPrimaryData():

    print("Logging in...")
    driver = webdriver.Chrome(options=options)
    driver.get("https://portal.flatironschool.com/sign_in")
    time.sleep(1)

    email = driver.find_elements(By.NAME, 'user[email]')
    pw = driver.find_elements(By.NAME, 'user[password]')
    login = driver.find_elements(By.NAME, 'commit')

    email[0].send_keys('natekist@outlook.com')
    pw[0].send_keys('jfq@zhb6wub*KCQ*hxd')
    login[0].click()
    
    # Loop through the phases 
    for n in course_info:
        
        # Make a phase_data item to be later added to course_info dictionary
        n['phase_data'] = []

        # Get and parse the html source on the phase page
        print("Getting ", n['phase_title'], "...", sep="")
 
        driver.get(n['phase_link'])
        time.sleep(.5)
        source = driver.page_source
        soup = BeautifulSoup(source, 'html.parser')
        regex = re.compile("item-group-condensed context_module*")
        col_headings = soup.find_all('div', {'class':regex})

        # Loop through the collapsible headings
        for index, val in enumerate(col_headings):
            
            # Get the title of the heading and get all the links under it
            col_heading_title = val.attrs["aria-label"]
            links = val.find_all('a', {'class':'ig-title title item_link'})

            # Make sure it's not a heading with zero links
            if len(links) > 0:
                col_heading_title = "".join(i for i in col_heading_title if i in string.printable).strip()
            else:
                continue

            # Create a variable for new heading to be added
            new_heading = {
                "heading_title":col_heading_title,
                'heading_data':[]
            }

            # Loop through the links in the collapsible heading
            for t in links:
                title = t.attrs['title']
                href = t.attrs['href']
                full_url = urljoin(n['phase_link'], href)
                title = "".join(i for i in title if i in string.printable).strip()
                new_link = {
                    'link_title':title,
                    'link_url':full_url,
                    'link_git':"",
                    'link_vim':"",
                    'link_done':0
                }
                new_heading['heading_data'].append(new_link)

            # Add the new heading to the phase list item
            n['phase_data'].append(new_heading)
    print("Finished getting primary course data.")

def save_info():
    with open('course_info.json', 'w') as f:
        json.dump(course_info, f)
        
# Prints out the phase/heading/links - print it in order of 1) primary content, 2) lecture, 3) exit tickets, 4) quizes
def print_course_info():
    
    for i in course_info:
        # Print the phase name
        print(f"\n\n{i['phase_title']}")
        
        for j in i['phase_data']:
            print(f"\n{j['heading_title']}\n")
            
            for l in j['heading_data']:
                if 'Quiz' not in l['link_title'] and 'Exit Ticket' not in l['link_title'] and 'Lecture' not in l['link_title']: 
                    print(f" - {l['link_title']}")
                    
            for l in j['heading_data']:
                if 'Lecture' in l['link_title']: 
                    print(f" - {l['link_title']}")
                    
            for l in j['heading_data']:
                if 'Exit Ticket' in l['link_title']: 
                    print(f" - {l['link_title']}")
            
            for l in j['heading_data']:
                if 'Quiz' in l['link_title']: 
                    print(f" - {l['link_title']}")

# %%
# Check how many links there are
count_total = 0
count_done = 0

for i in course_info:
    for j in i['phase_data']:
        for l in j['heading_data']:
            count_total+=1
            if l['link_done'] !=0:
                count_done +=1

count_not_done_at_start = count_total - count_done
print(f"There are {count_total} total lesson links, of which {count_not_done_at_start} still need to be checked for external links.\n")

if (count_total - count_done) > 0:
    print("Logging in...")
    driver = webdriver.Chrome(options=options)
    driver.get("https://portal.flatironschool.com/sign_in")
    time.sleep(1)

    email = driver.find_elements(By.NAME, 'user[email]')
    pw = driver.find_elements(By.NAME, 'user[password]')
    login = driver.find_elements(By.NAME, 'commit')

    email[0].send_keys('natekist@outlook.com')
    pw[0].send_keys('jfq@zhb6wub*KCQ*hxd')
    login[0].click()

    count_done = 0
    for i in course_info:
        for j in i['phase_data']:
            for l in j['heading_data']:
                if l['link_done'] == 0:
                    count_done+=1
                    print(f"{count_done:>3}/{count_not_done_at_start:>}: Checking {l['link_title']} ", sep="", end="")
                    driver.get(l['link_url'])
                    for _ in range(1, 4):
                        time.sleep(1)
                        source = driver.page_source
                        # every 3 seconds check for github link, max of 15 seconds waiting
                        start = source.find("https://github.com/learn-co-curriculum")
                        if start != -1:
                            end = source.find('"', start) 
                            l['link_git'] = (source[start:end].strip())
                            print("[GH]", end="")
                            break
                        start = source.find("https://player.vimeo.com/")
                        if start != -1:
                            end = source.find('?', start) 
                            l['link_vim'] = (source[start:end].strip())
                            print("[VIM]", end="")
                            break
                    l['link_done'] = 1
                    print("")
                    save_info()
# Out:
# There are 52 total lesson links, of which 0 still need to be checked for external links.

# %% [markdown]
# Load the course info from file

# %%
if os.path.exists('course_info.json'):
    with open('course_info.json', 'r') as f:
        course_info = json.load(f)

    print("Saved course info found/loaded.\n")
else:
    print("No saved course info.  Getting primary course data...\n")
    getPrimaryData()
    save_info()
    print("Course info saved to file.")
# Out:
# Saved course info found/loaded.

# %%
print_course_info()
# Out:
# Pre-work
#
# Introduction
#
#  - Welcome to Prep!
#  - The Structure of This Course
#  - Your First Jupyter Notebook!
#
# Prep Pre-test
#
#  - Prep Pre-Test
#
# Python Essentials
#
#  - Introduction to Variables: Variable Assignment
#  - Introduction to Variables: Strings
#  - Introduction to Variables: Strings - Lab
#  - Introduction to Variables: Numeric Types and Booleans
#  - Introduction to Variables: Strings and Numeric Types - Lab
#  - Introduction to Variables: Variable Assignment - Lab
#  - Control Flow: Conditionals
#  - Control Flow: Conditionals - Lab
#  - Working with Lists
#  - Working with Lists - Lab
#  - Working With Dictionaries
#  - Working with Dictionaries - Lab
#  - Built-in Python Operators, Functions and Methods
#  - Built-in Python Operators, Functions, and Methods - Lab
#  - Python Essentials - Cumulative Lab
#
# Python Loops & Functions
#
#  - Looping Over Collections
#  - Looping Over Collections - Lab
#  - While Loops, Break and Continue
#  - While Loops, Break and Continue - Lab
#  - Using Nested Loops
#  - Using Nested Loops - Lab
#  - Creating Functions
#  - Creating Functions - Lab
#  - Functions with Arguments
#  - Functions With Arguments - Lab
#  - User Input and Output in Python
#  - Python Loops and Functions - Cumulative Lab
#
# Statistical Measures
#
#  - Introduction to Numpy
#  - Getting Started with NumPy
#  - Getting Started with NumPy - Lab
#  - Measures of Central Tendency
#  - Measures of Dispersion
#  - Implementing Statistics with Functions - Lab
#  - Covariance and Correlation
#  - Covariance and Correlation - Lab
#  - Statistical Measures - Cumulative Lab
#  - Measures of Central Tendency - Quiz
#  - Measures of Dispersion - Quiz
#
# Data Visualization
#
#  - Data Visualization
#  - Data Visualization - Lab
#  - Customizing Visualizations with Matplotlib
#  - Customizing Visualizations with Matplotlib - Lab
#  - Data Visualization - Best Practices and Common Mistakes
#  - Seaborn
#  - Seaborn - Lab
#  - Data Visualization - Cumulative Lab
#
# Assessment
#
#  - Prep Post-Test
#
# The End!
#
#  - You Have Completed the Prep!

# %%
course_info

# %% [markdown]
# The cell below run through the course phases and lessons and puts all links (FIS, GH, VIM) next to each.  It includes all course items.

# %%
all_text = ""
for i in course_info:
    phase_title = i['phase_title']
    
    # Print the phase name
    print(f"\n\n{phase_title}")
    all_text = all_text + '<button type="button" class="collapsible"><h3>' + phase_title + '</h3></button><div class="content"><br>'

    for j in i['phase_data']:
        heading_title = j['heading_title']
        print(f"\n{heading_title}\n")
        all_text = all_text + "<b>" + heading_title + "</b><ul>"

        for l in j['heading_data']:
            print(f" - {l['link_title']}")
            if l['link_git'] == "" and l['link_vim'] == "":
                all_text = all_text + '<li>' + l['link_title'] + '  <a href="' + l['link_url'] + '"' + ' target="blank_">' + '[FIS]' + '</a></li>'
            elif l['link_git'] != "":
                all_text = all_text + '<li>' + l['link_title']  + '  <a href="' + l['link_url'] + '"' + ' target="blank_">' + '[FIS]' + '</a>' + '  <a href="' + l['link_git'] + '"' + ' target="blank_">' + '[GH] ' + '</a></li>'
            else:
                all_text = all_text + '<li>' + l['link_title']  + '  <a href="' + l['link_url'] + '"' + ' target="blank_">' + '[FIS]' + '</a>' + '  <a href="' + l['link_vim'] + '"' + ' target="blank_">' + '[VIM] ' + '</a></li>'
        all_text = all_text + "</ul>"   
    all_text = all_text + "</div>"
save_html_file("DS_Links_All.html")

# %% [markdown]
# The cell below takes course_info dictionary and turns it into a collapsible HTML file.  It ignores internal internal Flatiron school items like quizzes and exit tickets, and does not include Flatiron links (assumes course access is expired).

# %%
all_text = ""
for i in course_info:
    phase_title = i['phase_title']
    
    # Print the phase name
    print(f"\n\n{phase_title}")
    all_text = all_text + '<button type="button" class="collapsible"><h3>' + phase_title + '</h3></button><div class="content"><br>'

    for j in i['phase_data']:
        heading_title = j['heading_title']
        print(f"\n{heading_title}\n")
        all_text = all_text + "<b>" + heading_title + "</b><ul>"

        for l in j['heading_data']:
            if 'Quiz' in l['link_title'] or 'Exit Ticket' in l['link_title']:
                continue
            else:
                print(f" - {l['link_title']}")
                if l['link_git'] == "" and l['link_vim'] == "":
                    all_text = all_text + '<li>' + l['link_title']
                elif l['link_git'] != "":
                    all_text = all_text + '<li>' + l['link_title'] + '  <a href="' + l['link_git'] + '"' + ' target="blank_">' + '[GH] ' + '</a></li>'
                else:
                    all_text = all_text + '<li>' + l['link_title']  + '  <a href="' + l['link_vim'] + '"' + ' target="blank_">' + '[VIM] ' + '</a></li>'
        all_text = all_text + "</ul>"   
    all_text = all_text + "</div>"
save_html_file("DS_Links.html")
# Out:
# Pre-work
#
# Introduction
#
#  - Welcome to Prep!
#  - The Structure of This Course
#  - Your First Jupyter Notebook!
#
# Prep Pre-test
#
#  - Prep Pre-Test
#
# Python Essentials
#
#  - Introduction to Variables: Variable Assignment
#  - Introduction to Variables: Strings
#  - Introduction to Variables: Strings - Lab
#  - Introduction to Variables: Numeric Types and Booleans
#  - Introduction to Variables: Strings and Numeric Types - Lab
#  - Introduction to Variables: Variable Assignment - Lab
#  - Control Flow: Conditionals
#  - Control Flow: Conditionals - Lab
#  - Working with Lists
#  - Working with Lists - Lab
#  - Working With Dictionaries
#  - Working with Dictionaries - Lab
#  - Built-in Python Operators, Functions and Methods
#  - Built-in Python Operators, Functions, and Methods - Lab
#  - Python Essentials - Cumulative Lab
#
# Python Loops & Functions
#
#  - Looping Over Collections
#  - Looping Over Collections - Lab
#  - While Loops, Break and Continue
#  - While Loops, Break and Continue - Lab
#  - Using Nested Loops
#  - Using Nested Loops - Lab
#  - Creating Functions
#  - Creating Functions - Lab
#  - Functions with Arguments
#  - Functions With Arguments - Lab
#  - User Input and Output in Python
#  - Python Loops and Functions - Cumulative Lab
#
# Statistical Measures
#
#  - Introduction to Numpy
#  - Getting Started with NumPy
#  - Getting Started with NumPy - Lab
#  - Measures of Central Tendency
#  - Measures of Dispersion
#  - Implementing Statistics with Functions - Lab
#  - Covariance and Correlation
#  - Covariance and Correlation - Lab
#  - Statistical Measures - Cumulative Lab
#
# Data Visualization
#
#  - Data Visualization
#  - Data Visualization - Lab
#  - Customizing Visualizations with Matplotlib
#  - Customizing Visualizations with Matplotlib - Lab
#  - Data Visualization - Best Practices and Common Mistakes
#  - Seaborn
#  - Seaborn - Lab
#  - Data Visualization - Cumulative Lab
#
# Assessment
#
#  - Prep Post-Test
#
# The End!
#
#  - You Have Completed the Prep!
#
#
# Phase 1 - Python, Data Analysis, SQL, Web Scraping, etc.
#
# Unlock Course (Flex)
#
#  - Unlock Phase 1
#
# Table of Contents
#
#  - Table of Contents (Live)
#
# Topic 0: Welcome
#
#  - Welcome
#
# Topic 1: Getting Started with Data Science
#
#  - Topic 1 Lesson Priorities (Live)
#  - Getting Started with Data Science - Introduction
#  - The Data Science Process
#  - Problems Data Science Can Solve
#  - PEP8
#  - Data Privacy and Data Ethics
#  - Lecture: Data Science Environments (Live)
#  - Setting up a Professional Data Science Environment - Introduction
#  - Setting up a Professional Data Science Environment - MacOS Installation
#  - Setting up a Professional Data Science Environment - Windows Installation
#  - Setting up a Professional Data Science Environment - Configuring Git and Anaconda
#  - Running Jupyter Notebooks Locally
#  - Running Jupyter Notebooks Locally - Lab
#  - Getting Started with Data Science - Recap
#
# Orientation Quiz (Flex)
#
#
# Topic 2: Bash and Git
#
#  - Topic 2 Lesson Priorities (Live)
#  - Bash and Git - Introduction
#  - The Bash Shell
#  - Short Video: Bash
#  - Git Version Control 101
#  - Lecture: Bash and Git Introduction (Flex)
#  - Lecture: Bash and Git Introduction (Live)
#  - Getting Started with Git
#  - Git Practice
#  - .gitignore
#  - Lecture: Git Fundamentals (Flex)
#  - Lecture: Git Fundamentals (Live)
#  - Collaborating with Git Branches
#  - Git Merge - Lab
#  - Git Stash - Lab
#  - Git Resources
#  - Lecture: Git Collaboration (Live)
#  - Bash and Git - Recap
#
# Topic 3: Data Analysis in Base Python
#
#  - Topic 3 Lesson Priorities (Live)
#  - Data Analysis in Base Python - Introduction
#  - Lecture: Python Data Manipulation (Live)
#  - Short Video: List Comprehensions and Dictionary Comprehensions
#  - File Input and Output in Python
#  - CSV
#  - Lecture: Data Analysis with CSV Files (Flex)
#  - Lecture: Data Analysis with CSV Files (Live)
#  - JSON
#  - JSON - Lab
#  - Working with Known JSON Schemas
#  - Working with Known JSON Schemas - Lab
#  - Exploring and Transforming JSON Schemas
#  - Exploring and Transforming JSON Schemas - Lab
#  - Lecture: Data Analysis with JSON Files (Flex)
#  - Data Serialization Formats - Cumulative Lab
#  - Data Analysis in Base Python - Recap
#
# Topic 4: Data Analysis in Pandas
#
#  - Topic 4 Lesson Priorities (Live)
#  - Data Analysis in Pandas - Introduction
#  - Introducing Python Libraries
#  - Accessing Data within Pandas
#  - Accessing Data within Pandas - Lab
#  - Importing Data Using Pandas
#  - Importing Data Using Pandas - Lab
#  - Understanding Pandas Series and DataFrames
#  - Understanding Pandas Series and DataFrames - Lab
#  - Statistical Methods in Pandas
#  - Statistical Methods in Pandas - Lab
#  - Kaggle and The Ames Housing Dataset
#  - Data Visualization with Pandas
#  - Lecture: Data Visualization (Flex)
#  - Short Video: Basic Plotting with MatPlotLib
#  - EDA with Pandas - Cumulative Lab
#  - Data Analysis in Pandas - Recap
#
# Topic 5: Data Cleaning in Pandas
#
#  - Topic 5 Lesson Priorities (Live)
#  - Data Cleaning in Pandas - Introduction
#  - Lambda Functions
#  - Lambda Functions - Lab
#  - Dealing with Missing Data
#  - Dealing with Missing Data - Lab
#  - More on Missing Data
#  - More on Missing Data - Lab
#  - Lecture: Pandas Data Cleaning (Flex)
#  - Pandas Groupby
#  - Combining DataFrames With Pandas
#  - Combining DataFrames With Pandas - Lab
#  - Pivot Tables With Pandas
#  - Pivot Tables with Pandas - Lab
#  - Short Video: Pandas GroupBy
#  - Pandas Data Cleaning - Cumulative Lab
#  - Data Cleaning in Pandas - Recap
#
# Topic 6: Getting Started with SQL
#
#  - Topic 6 Lesson Priorities (Live)
#  - Getting Started with SQL - Introduction
#  - Connecting to SQL Databases
#  - Selecting Data with SQL
#  - Filtering Data with SQL
#  - Filtering Data with SQL - Lab
#  - Ordering and Limiting Data with SQL
#  - Filtering, Ordering, and Limiting Data with SQL - Lab
#  - Grouping Data with SQL
#  - Grouping Data with SQL - Lab
#  - Database Admin 101
#  - Database Admin 101 - Lab
#  - SQL Database Data Types
#  - Getting Started with SQL - Recap
#
# Topic 7: SQL Table Relations
#
#  - Topic 7 Lesson Priorities (Live)
#  - SQL Table Relations - Introduction
#  - Join Statements
#  - Join Statements - Lab
#  - One-to-Many and Many-to-Many Joins
#  - One-to-Many and Many-to-Many Joins - Lab
#  - Short Video: SQL JOINs
#  - SQL Subqueries
#  - SQL Subqueries - Lab
#  - Using SQL with Pandas
#  - Using SQL with Pandas - Lab
#  - SQL Interview Questions - Lab
#  - SQL - Cumulative Lab
#  - SQL Table Relations - Recap
#
# Topic 8: Other Database Structures
#
#  - Topic 8 Lesson Priorities (Live)
#  - NoSQL Databases - Introduction
#  - NoSQL Databases: Document Stores
#  - MongoDB
#  - MongoDB - Lab
#  - Lecture: NoSQL
#  - NoSQL Databases - Summary
#
# Topic 9: APIs
#
#  - Topic 9 Lesson Priorities (Live)
#  - APIs - Introduction
#  - Introduction to APIs
#  - The Client Server Model
#  - HTTP Request/Response Cycle - Codealong
#  - HTTP Request/Response Cycle - Lab
#  - OAuth - Open Authorization
#  - Using the Yelp API - Codealong
#  - Reading API Documentation
#  - Folium - Codealong
#  - APIs - Cumulative Lab
#  - APIs - Recap
#
# Topic 10: HTML, CSS and Web Scraping
#
#  - Topic 10 Lesson Priorities (Live)
#  - HTML, CSS and Web Scraping - Introduction
#  - HTML Introduction
#  - Researching HTML Elements
#  - Separating Content and Presentation
#  - Intro to CSS
#  - CSS Code Along
#  - My Little Rainbow
#  - An Introduction to Web Scraping and Beautiful Soup
#  - Web Scraping In Practice
#  - Web Scraping - Lab
#  - Scraping Images
#  - Scraping Concerts - Lab
#  - HTML, CSS and Web Scraping -  Recap
#
# Milestones
#
#  - Introduction to Python DataCamp Certification (PDF Upload)
#  - Data Serialization Formats Checkpoint
#  - (CodeGrade) EDA with Pandas Checkpoint
#  - (CodeGrade) Pandas Data Cleaning Checkpoint
#  - (CodeGrade) SQL Checkpoint
#  - Phase 1 Project Description
#  - Repository Readability
#  - Presentation Content
#  - Slide Style
#  - Phase 1 Project Proposal
#  - Phase 1 Project - GitHub Repository URL
#  - Phase 1 Project - PDFs
#  - Blogging Overview
#  - Phase 1 Blog Post
#
#
# Phase 2 - Statistics / Linear Regression Modeling
#
# Unlock Course (Flex)
#
#  - Unlock Phase 2
#
# Table of Contents
#
#  - Table of Contents (Live)
#  - Table of Contents (Flex)
#
# Topic 11: Combinatorics and Probability
#
#  - Topic 11 Lesson Priorities (Live)
#  - Combinatorics and Probability - Introduction
#  - What is Probability?
#  - Introduction to Sets
#  - Introduction to Sets - Lab
#  - Introduction to Probability
#  - Introduction to Probability - Lab
#  - Permutations and Factorials
#  - Permutations and Factorials - Lab
#  - Combinations
#  - Combinations - Lab
#  - Conditional Probability
#  - Conditional Probability - Lab
#  - Partitioning and the Law of Total Probability
#  - Partitioning and Law of Total Probability - Lab
#  - Simulations with Conditional and Total Probability - Lab
#  - Lecture: Probability (Flex)
#  - Lecture: Probability (Live)
#  - Combinatorics and Probability - Recap
#
# Topic 12: Statistical Distributions
#
#  - Topic 12 Lesson Priorities (Live)
#  - Statistical Distributions - Introduction
#  - Introduction to Sampling
#  - Statistical Distributions and Their Use Cases
#  - The Probability Mass Function (PMF)
#  - The Probability Mass Function - Lab
#  - The Probability Density Function (PDF)
#  - The Probability Density Function - Lab
#  - The Cumulative Distribution Function
#  - The Cumulative Distribution Function - Lab
#  - Bernoulli and Binomial Distribution
#  - Bernoulli and Binomial Distribution - Lab
#  - Lecture: Statistical Distributions: Density Functions (Flex)
#  - The Normal Distribution
#  - The Normal Distribution - Lab
#  - The Standard Normal Distribution
#  - The Standard Normal Distribution - Lab
#  - Skewness and Kurtosis
#  - Skewness and Kurtosis - Lab
#  - Lecture: Statistical Distributions: The Normal Distribution (Flex)
#  - Statistical Distributions - Recap
#
# Topic 13: Central Limit Theorem and Confidence Intervals
#
#  - Topic 13 Lesson Priorities (Live)
#  - Central Limit Theorem and Confidence Intervals - Introduction
#  - Central Limit Theorem
#  - Central Limit Theorem - Lab
#  - Sampling Statistics - Lab
#  - Confidence Intervals - Lab
#  - Confidence Intervals with T-Distribution
#  - Confidence Intervals with T Distribution - Lab
#  - Introduction to Statistical Significance
#  - Lecture: Confidence Intervals (Flex)
#  - Short Video: Calculating a Confidence Interval
#  - Central Limit Theorem and Confidence Intervals - Recap
#
# Topic 14: Hypothesis Testing
#
#  - Topic 14 Lesson Priorities (Live)
#  - Hypothesis Testing - Introduction
#  - Introduction to Experimental Design
#  - Statistical Testing with z-score and p-value
#  - P-Values and the Null Hypothesis
#  - Short Video: Hypothesis Testing in General
#  - One-Sample z-Test
#  - One-Sample z-test - Lab
#  - Lecture: Hypothesis Testing: z-Tests (Flex)
#  - Conducting T-Tests
#  - One Sample T-Test - Lab
#  - Two Sample T-Test - Lab
#  - Type I and Type II errors
#  - Type I and Type II Errors - Lab
#  - Resampling Methods
#  - Resampling Methods - Lab
#  - Lecture: Hypothesis Testing: t-Tests (Flex)
#  - Hypothesis Testing - Recap
#
# Topic 15: Statistical Power and ANOVA
#
#  - Topic 15 Lesson Priorities (Live)
#  - Statistical Power and ANOVA -  Introduction
#  - Effect Size
#  - Statistical Power
#  - Statistical Power - Lab
#  - Welch's T-Test
#  - Welch's T-test - Lab
#  - Effect Size, P-Values and Power - Lab
#  - The Multiple Comparisons Problem
#  - Goodhart's Law and Metric Tracking
#  - The Kolmogorov-Smirnov Test
#  - The Kolmogorov-Smirnov Test - Lab
#  - ANOVA
#  - ANOVA  - Lab
#  - Lecture: ANOVA (Flex)
#  - Chi-Square Tests
#  - Lecture: Chi-Square Tests (Flex)
#  - Hypothesis Testing - Cumulative Lab
#  - Statistical Power and ANOVA - Recap
#
# Topic 16: AB Testing
#
#  - Topic 16 Lesson Priorities (Live)
#  - AB Testing - Introduction
#  - A/B Testing
#  - A/B Testing - Lab
#  - Lecture: A/B Testing: Design (Flex)
#  - In Depth A/B Testing - Lab
#  - Lecture: A/B Testing: Analysis (Flex)
#  - Website AB Testing - Lab
#  - AB Testing - Recap
#
# Topic 17: Bayesian Statistics
#
#  - Topic 17 Lesson Priorities (Live)
#  - Bayesian Statistics - Introduction
#  - Bayesians vs Frequentists
#  - Bayes' Theorem
#  - Bayes' Theorem - Lab
#  - The Monty Hall Problem
#  - Maximum Likelihood Estimation (MLE)
#  - Maximum A Posteriori Estimation (MAP) and Multinomial Bayes
#  - Lecture: Bayesian Reasoning (Flex)
#  - Bayesian Statistics - Recap
#
# Topic 18: Introduction to Linear Regression
#
#  - Topic 18 Lesson Priorities (Live)
#  - Introduction to Linear Regression - Introduction
#  - Statistical Modeling
#  - Simple Linear Regression from Scratch - Codealong
#  - Regression Model Evaluation
#  - Coefficient of Determination - Lab
#  - Lecture: Simple Linear Regression: Part 1 (Flex)
#  - Linear Regression in StatsModels
#  - Linear Regression in StatsModels - Lab
#  - Lecture: Simple Linear Regression: Part 2 (Flex)
#  - Introduction to Linear Regression - Recap
#
# Topic 19: Multiple Linear Regression
#
#  - Topic 19 Lesson Priorities (Live)
#  - Multiple Linear Regression - Introduction
#  - Multiple Linear Regression
#  - Multiple Linear Regression in StatsModels
#  - Multiple Linear Regression in StatsModels - Lab
#  - Multiple Regression Model Evaluation
#  - Lecture: Multiple Linear Regression: Part 1 (Flex)
#  - Dealing with Categorical Variables
#  - Interpreting One-Hot Encoded Coefficients
#  - Short Video: One-Hot Encoding
#  - Dealing with Categorical Variables - Lab
#  - Lecture: Multiple Linear Regression: Part 2 (Flex)
#  - Multiple Linear Regression - Cumulative Lab
#  - Multiple Linear Regression - Recap
#  - Lecture: Categories and Transformations (Flex)
#
# Topic 20: Regression Diagnostics
#
#  - Topic 20 Lesson Priorities (Live)
#  - Regression Diagnostics - Introduction
#  - Linear Transformations
#  - Linear Transformations - Lab
#  - Log Transformations
#  - Log Transformations - Lab
#  - Interactions
#  - Interactions - Lab
#  - Polynomial Regression
#  - Polynomial Regression - Lab
#  - Lecture: Feature Selection and Engineering (Flex)
#  - Assumptions for Linear Regression
#  - The Linearity Assumption
#  - Multicollinearity of Features
#  - Multicollinearity of Features - Lab
#  - The Normality Assumption
#  - Short Video: QQ Plots
#  - The Homoscedasticity Assumption
#  - Regression Diagnostics - Recap
#  - Lecture: Assumptions of Linear Regression (Flex)
#
# Milestones
#
#  - (CodeGrade) Hypothesis Testing Checkpoint
#  - (CodeGrade) Bayesian Statistics Checkpoint
#  - (CodeGrade) Phase 2 Code Challenge
#  - Phase 2 Project Description
#  - Phase 2 Project Proposal
#  - Phase 2 Project - PDFs
#  - Phase 2 Project - GitHub Repository URL
#  - Blogging Overview
#  - Phase 2 Blog Post
#
# APPENDIX: Combinatorics
#
#  - Combinatorics: Recursive Functions
#  - Combinatorics: Recursive Functions - Lab
#
# APPENDIX: More Distributions
#
#  - The Uniform Distribution
#  - Poisson Distribution
#  - The Poisson Distribution - Lab
#  - The Exponential Distribution
#  - The Exponential Distribution - Lab
#
# APPENDIX: Monte Carlo
#
#  - (Re)sampling: Monte Carlo Simulations
#  - (Re)sampling: Monte Carlo Simulations - Lab
#
# APPENDIX : Multiple Linear Regression Project
#
#  - Obtaining Your Data
#  - Obtaining Your Data - Lab
#  - Scrubbing and Cleaning Data
#  - Scrubbing and Cleaning Data - Lab
#  - Exploring Your Data
#  - Exploring Your Data - Lab
#
#
# Phase 3 - Classification Modeling / Machine Learning Fundamentals
#
# Unlock Course (Flex)
#
#  - Unlock Phase 3
#
# Topic 21: Object-Oriented Programming and Scikit-Learn
#
#  - Topic 21 Lesson Priorities (Live)
#  - Object-Oriented Programming - Introduction
#  - Classes and Instances
#  - Classes and Instances - Lab
#  - Instance Methods
#  - Instance Methods - Lab
#  - A Deeper Dive into self
#  - Object Attributes - Lab
#  - Object Initialization
#  - Object Initialization - Lab
#  - Lecture: Python OOP (Flex)
#  - Inheritance
#  - Inheritance - Lab
#  - OOP with Scikit-Learn
#  - OOP with Scikit-Learn - Lab
#  - Lecture: OOP with Scikit-Learn (Flex)
#  - Short Video: Debugging with OOP
#  - Preprocessing with scikit-learn - Cumulative Lab
#  - Object-Oriented Programming - Recap
#
# Topic 22: Linear Algebra and Calculus
#
#  - Topic 22 Lesson Priorities (Live)
#  - Linear Algebra and Calculus - Introduction
#  - Motivation for Linear Algebra in Data Science
#  - Systems of Linear Equations
#  - Systems of Linear Equations - Lab
#  - Scalars, Vectors, Matrices, and Tensors - Code Along
#  - Matrix Multiplication - Code Along
#  - Short Video: Matrix Multiplication
#  - Solving Systems of Linear Equations with NumPy - Code Along
#  - Solving Systems of Linear Equations with NumPy - Lab
#  - Regression Analysis using Linear Algebra and NumPy - Code Along
#  - Regression with Linear Algebra - Lab
#  - Computational Complexity: From OLS to Gradient Descent
#  - Lecture: Linear Algebra (Flex)
#  - Introduction to Derivatives
#  - Introduction to Derivatives - Lab
#  - Derivatives of Non-Linear Functions
#  - Rules for Derivatives
#  - Derivatives: Conclusion
#  - Lecture: Calculus and Cost Functions
#  - Introduction to Gradient Descent
#  - Gradient Descent: Step Sizes
#  - Gradient Descent: Step Sizes - Lab
#  - Gradient Descent in 3D
#  - The Gradient in Gradient Descent
#  - Short Video: The Gradient
#  - Gradient to Cost Function
#  - Applying Gradient Descent - Lab
#  - Lecture: Gradient Descent (Flex)
#  - Linear Algebra and Calculus - Recap
#
# Topic 23: Machine Learning Fundamentals
#
#  - Topic 23 Lesson Priorities (Live)
#  - Machine Learning Fundamentals - Introduction
#  - Data Science Processes
#  - Statistical Learning Theory
#  - Regression Model Validation
#  - Regression Model Validation - Lab
#  - Introduction to Cross-Validation
#  - Introduction to Cross-Validation - Lab
#  - Short Video: Cross-Validation
#  - Bias-Variance Tradeoff
#  - Bias-Variance Tradeoff - Lab
#  - Short Video: Bias-Variance Tradeoff
#  - Lecture: Inference vs. Prediction (Flex)
#  - Lecture: Model Validation (Flex)
#  - Lecture: Data Leakage (Flex)
#  - Ridge and Lasso Regression
#  - Ridge and Lasso Regression - Lab
#  - Feature Selection Methods
#  - Extensions to Linear Models - Lab
#  - Lecture: Regularization (Flex)
#  - Machine Learning Fundamentals - Cumulative Lab
#  - Machine Learning Fundamentals - Recap
#
# Topic 24: Logistic Regression
#
#  - Topic 24 Lesson Priorities (Live)
#  - Logistic Regression - Introduction
#  - Introduction to Supervised Learning
#  - Linear to Logistic regression
#  - Fitting a Logistic Regression Model - Lab
#  - Logistic Regression in scikit-learn
#  - Logistic Regression in scikit-learn - Lab
#  - Lecture: Logistic Regression: Introduction (Flex)
#  - MLE Review
#  - MLE and Logistic Regression
#  - Gradient Descent Review
#  - Gradient Descent - Lab
#  - Coding Logistic Regression From Scratch - Lab
#  - Lecture: Implementing and Interpreting Logistic Regression (Flex)
#  - Logistic Regression - Recap
#
# Topic 25: Classification Metrics
#
#  - Topic 25 Lesson Priorities (Live)
#  - Classification Metrics - Introduction
#  - Confusion Matrices
#  - Visualizing Confusion Matrices - Lab
#  - Evaluation Metrics
#  - Evaluating Logistic Regression Models - Lab
#  - Lecture: Evaluating Classification Models: Confusion Matrix (Flex)
#  - ROC Curves and AUC
#  - ROC Curves and AUC - Lab
#  - Logistic Regression Model Comparisons - Lab
#  - Class Imbalance Problems
#  - Class Imbalance Problems - Lab
#  - Lecture: Evaluating Classification Models: Predicted Probabilities (Flex)
#  - Lecture: Iterative Modeling Workflow (Flex)
#  - Logistic Regression - Cumulative Lab
#  - Classification Metrics - Recap
#
# Topic 26: Decision Trees
#
#  - Topic 26 Lesson Priorities (Live)
#  - Decision Trees - Introduction
#  - Introduction to Decision Trees
#  - Entropy and Information Gain
#  - ID3 Classification Trees: Perfect Split with Information Gain - Lab
#  - Building Trees using scikit-learn
#  - Building Trees using scikit-learn - Lab
#  - Hyperparameter Tuning and Pruning in Decision Trees
#  - Hyperparameter Tuning and Pruning in Decision Trees - Lab
#  - Regression with CART Trees
#  - Regression with CART Trees - Lab
#  - Regression Trees and Model Optimization - Lab
#  - Lecture: Decision Trees (Flex)
#  - Short Video: Regression Trees
#  - Decision Trees - Recap
#
# Topic 27: K Nearest Neighbors
#
#  - Topic 27 Lesson Priorities (Live)
#  - K-Nearest Neighbors - Introduction
#  - Distance Metrics
#  - Distance Metrics - Lab
#  - K-Nearest Neighbors
#  - K-Nearest Neighbors - Lab
#  - Finding the Best Value for K
#  - KNN with scikit-learn
#  - KNN with scikit-learn - Lab
#  - Lecture: K-Nearest Neighbors (KNN) (Flex)
#  - Nonparametric ML Models - Cumulative Lab
#  - K-Nearest Neighbors - Recap
#
# Topic 28: Bayes Classification
#
#  - Topic 28 Lesson Priorities (Live)
#  - Bayesian Classification - Introduction
#  - Classifiers with Bayes
#  - Gaussian Naive Bayes
#  - Gaussian Naive Bayes - Lab
#  - Document Classification with Naive Bayes
#  - Document Classification with Naive Bayes - Lab
#  - Lecture: Naive Bayes (Flex)
#  - Short Video: Naive Bayes by Hand
#  - Bayesian Classification - Recap
#
# Topic 29: Model Tuning and Pipelines
#
#  - Topic 29 Lesson Priorities (Live)
#  - Model Tuning and Pipelines - Introduction
#  - GridSearchCV
#  - Introduction to Pipelines
#  - Pipelines in scikit-learn - Lab
#  - Refactoring Your Code to Use Pipelines
#  - Short Video: Pipelines
#  - Lecture: Model Tuning (Flex)
#  - Pickle
#  - Pickling and Deploying Pipelines
#  - Model Tuning and Pipelines - Recap
#
# Topic 30: Ensemble Methods
#
#  - Topic 30 Lesson Priorities (Live)
#  - Ensemble Methods - Introduction
#  - Ensemble Methods
#  - Random Forests
#  - Tree Ensembles and Random Forests - Lab
#  - GridSearchCV - Lab
#  - Lecture: Ensemble Methods: Bagging (Flex)
#  - Gradient Boosting and Weak Learners
#  - Gradient Boosting - Lab
#  - XGBoost
#  - XGBoost - Lab
#  - Lecture: Ensemble Methods: Boosting (Flex)
#  - Lecture: Modeling with Pipelines (Flex)
#  - Ensembles - Recap
#
# Milestones
#
#  - Object-Oriented Programming Checkpoint
#  - (CodeGrade) Object-Oriented Programming Checkpoint
#  - (CodeGrade) Machine Learning Fundamentals Checkpoint
#  - (CodeGrade) Logistic Regression Checkpoint
#  - (CodeGrade) Decision Trees Checkpoint
#  - Phase 3 Project Description
#  - Phase 3 Project - Choosing a Dataset
#  - Phase 3 Project Proposal
#  - Phase 3 Project - PDFs
#  - Phase 3 Project - GitHub Repository URL
#  - Blogging Overview
#  - Phase 3 Blog Post
#
# APPENDIX: More OOP
#
#  - Object Oriented Attributes with Functions
#  - Object Oriented Attributes With Functions - Lab
#  - Object Oriented Shopping Cart - Lab
#  - Building an Object-Oriented Simulation
#  - Building an Object-Oriented Simulation - Lab
#
# APPENDIX: More Linear Algebra
#
#  - Vector Addition and Broadcasting in NumPy - Code Along
#  - Vectors and Matrices in Numpy - Lab
#  - Properties of Dot Product - Lab
#  - Pure Python vs. Numpy - Lab
#
# APPENDIX: More On Derivatives
#
#  - Rules for Derivatives - Lab
#  - Derivatives: the Chain Rule
#  - Gradient to Cost Function - Appendix
#
# APPENDIX: Support Vector Machines
#
#  - Support Vector Machines - Introduction
#  - Introduction to Support Vector Machines
#  - Building an SVM from Scratch - Lab
#  - Building an SVM using scikit-learn - Lab
#  - The Kernel Trick
#  - Kernels in scikit-learn - Lab
#  - Support Vector Machines - Recap
#
#
# Phase 4 - Advanced Machine Learning
#
# Unlock Course (Flex)
#
#  - Unlock Phase 4
#
# Table of Contents
#
#  - Table of Contents (Live)
#
# Topic 31: Principal Component Analysis
#
#  - Topic 31 Lesson Priorities (Live)
#  - PCA - Introduction
#  - Unsupervised Learning
#  - The Curse of Dimensionality
#  - The Curse of Dimensionality - Lab
#  - Principal Component Analysis in scikit-learn
#  - Principal Component Analysis in scikit-learn - Lab
#  - Integrating PCA in Pipelines - Lab
#  - PCA for Facial Image Recognition
#  - Image Recognition with PCA - Lab
#  - PCA Background: Covariance Matrix and Eigendecomposition
#  - Performing Principal Component Analysis (PCA)
#  - Performing Principal Component Analysis (PCA) - Lab
#  - Lecture: Principal Component Analysis (PCA) (Flex)
#  - Short Video: Solving an Eigenvalue Problem
#  - Dimensionality Reduction - Cumulative Lab
#  - PCA - Recap
#
# Topic 32: Recommendation Systems
#
#  - Topic 32 Lesson Priorities (Live)
#  - Recommendation Systems - Introduction
#  - Introduction to Recommendation Systems
#  - Collaborative Filtering with Singular Value Decomposition
#  - Matrix Factorization with Alternating Least Squares
#  - Lecture: Singular Value Decomposition (SVD)
#  - Implementing Recommendation Engines with Surprise
#  - Implementing Recommender Systems - Lab
#  - Lecture: Recommendation Systems (Flex)
#  - Recommendation Systems - Recap
#
# Topic 33: Clustering
#
#  - Topic 33 Lesson Priorities (Live)
#  - Clustering - Introduction
#  - K-means Clustering
#  - K-means Clustering - Lab
#  - Lecture: K-Means Clustering (Flex)
#  - Hierarchical Agglomerative Clustering
#  - Common Problems with Clustering Algorithms
#  - Hierarchical Agglomerative Clustering - Codealong
#  - Semi-Supervised Learning and Look-Alike Models
#  - Lecture: Hierarchical Clustering (Flex)
#  - Short Video: Calculating a Silhouette Coefficient
#  - Market Segmentation with Clustering
#  - Market Segmentation with Clustering - Lab
#  - Clustering - Recap
#
# Topic 34: Exploring Time Series Data
#
#  - Topic 34 Lesson Priorities (Live)
#  - Exploring Time Series Data - Introduction
#  - Introduction to Time Series
#  - Managing Time Series Data - Lab
#  - Visualizing Time Series Data - Lab
#  - Lecture: Time Series Data Manipulation (Flex)
#  - Types of Trends
#  - Testing for Trends - Lab
#  - Removing Trends
#  - Removing Trends - Lab
#  - Time Series Decomposition
#  - Lecture: Time Series Trends and Stationarity (Flex)
#  - Exploring Time Series Data - Recap
#
# Topic 35: Modeling Time Series Data
#
#  - Topic 35 Lesson Priorities (Live)
#  - Modeling Time Series Data - Introduction
#  - Basic Time Series Models
#  - Basic Time Series Models - Lab
#  - Correlation and Autocorrelation in Time Series
#  - Correlation and Autocorrelation in Time Series - Lab
#  - ARMA Models
#  - ARMA Models in StatsModels
#  - ARMA Models in StatsModels - Lab
#  - Lecture: Time Series Modeling (Flex)
#  - Lecture: Time Series Modeling Walkthrough (Flex)
#  - Modeling Time Series Data - Recap
#
# Topic 36: Big Data and (Py)Spark
#
#  - Topic 36 Lesson Priorities (Live)
#  - Big Data and (Py)Spark - Introduction
#  - Introduction to Big Data
#  - Parallel and Distributed Computing with MapReduce
#  - (Py)Spark Basics
#  - Lecture: Big Data Introduction (Flex)
#  - Installing and Configuring PySpark with Docker
#  - Understanding SparkContext - Codealong
#  - Resilient Distributed Datasets (RDDs) - Lab
#  - Word Count with MapReduce - Lab
#  - Spark DataFrames
#  - Machine Learning with Spark
#  - Machine Learning with Spark - Lab
#  - Lecture: Spark (Flex)
#  - Short Video: sklearn to pyspark
#  - Building a Recommendation System in PySpark - Lab
#  - Big Data and (Py)Spark - Recap
#
# Topic 37: Natural Language Processing
#
#  - Topic 37 Lesson Priorities (Live)
#  - Natural Language Processing - Introduction
#  - NLP and Word Vectorization
#  - Word Vectorization - Lab
#  - Introduction to NLP with NLTK
#  - Introduction to Regular Expressions
#  - Regular Expressions - Codealong
#  - Lecture: NLP Pre-Processing (Flex)
#  - Short Video: The Bag of Words Model
#  - Feature Engineering for Text Data
#  - Corpus Statistics - Lab
#  - Context-Free Grammars and POS Tagging
#  - Context-Free Grammars - Codealong
#  - Lecture: NLP Vectorization (Flex)
#  - Short Video: TF-IDF Vectorization
#  - Text Classification
#  - Lecture: NLP Modeling (Flex)
#  - Text Classification - Cumulative Lab
#  - Natural Language Processing - Recap
#
# Topic 38: Neural Networks
#
#  - Topic 38 Lesson Priorities (Live)
#  - Neural Networks - Introduction
#  - Introduction to Neural Networks
#  - Introduction to Neural Networks - Lab
#  - Lecture: Neural Networks Architecture (Flex)
#  - Introduction to Keras
#  - Keras - Lab
#  - Deeper Neural Networks
#  - Deeper Neural Networks - Lab
#  - Image Classification with Multi-Layer Perceptrons
#  - Image Classification with MLPs - Lab
#  - Lecture: Intro to Keras and Tensorflow (Flex)
#  - Short Video: Regression with a Neural Network
#  - Neural Networks - Recap
#
# Topic 39: Tuning Neural Networks
#
#  - Topic 39 Lesson Priorities (Live)
#  - Tuning Neural Networks - Introduction
#  - Tuning Neural Networks with Regularization
#  - Tuning Neural Networks with Regularization - Lab
#  - Tuning Neural Networks with Normalization
#  - Tuning Neural Networks with Normalization - Lab
#  - Tuning and Optimizing Neural Networks - Lab
#  - Lecture: Network Regularization and Evaluation (Flex)
#  - Convolutional Neural Networks
#  - Convolutional Neural Networks - Codealong
#  - Building a CNN from Scratch - Lab
#  - Visualizing Intermediate Activations
#  - Visualizing Activation Functions - Lab
#  - Lecture: Convolutional Neural Networks (Flex)
#  - Tuning Neural Networks - Recap
#
# Topic 40: Amazon Web Services
#
#  - Topic 40 Lesson Priorities (Live)
#  - Amazon Web Services - Introduction
#  - Cloud Computing
#  - The AWS Ecosystem
#  - Amazon Simple Storage Service (S3)
#  - Introduction to Amazon SageMaker
#  - Data Science and Machine Learning Engineering
#  - Introduction to Flask
#  - Deploying a Model with Flask
#  - Introduction to Dash
#  - Deploying a Model with Dash
#  - Productionizing a Model with Docker and SageMaker
#  - Lecture: Cloud Services (Flex)
#  - Amazon Web Services - Recap
#
# Milestones
#
#  - (CodeGrade) Unsupervised ML Checkpoint
#  - (CodeGrade) Time Series Checkpoint
#  - (CodeGrade) NLP Checkpoint
#  - Blogging Overview
#  - Phase 4 Blog Post
#
# APPENDIX: More Time Series
#
#  - Time Series: SARIMA Models - Lab
#  - Time Series: Facebook Prophet - Lab
#
# APPENDIX: Graph Theory (Recommendation Systems)
#
#  - Graph Theory - Introduction
#  - Introduction to Graph Theory
#  - Introduction to NetworkX
#  - Introduction to NetworkX - Lab
#  - Simple and Shortest Paths
#  - Simple and Shortest Paths - Lab
#  - Node Centrality
#  - Node Centrality - Lab
#  - Network Clustering
#  - Network Clustering - Lab
#  - Network Connectivity:  Community Detection -Lab
#  - Recommendation Systems
#  - Amazon Recommendation System - Lab
#  - Graph Theory - Recap
#
# APPENDIX: Transfer Learning (Image Classification)
#
#  - Transfer Learning - Introduction
#  - Using Pretrained Networks
#  - Using Pretrained Networks - Codealong
#  - Image Classification - Lab
#  - Transfer Learning - Recap
#
# APPENDIX: Deep NLP
#
#  - Deep NLP with Word Embeddings - Introduction
#  - Word Embeddings
#  - Using Word2Vec
#  - Generating Word Embeddings - Lab
#  - Classification with Word Embeddings
#  - Classification with Word Embeddings - Codealong
#  - Sequence Model Use Cases
#  - Understanding Recurrent Neural Networks
#  - LSTMs and GRUs
#  - Deep NLP with Word Embeddings - Recap
#
#
# Phase 5 - Capstone
#
# Unlock Course
#
#  - Unlock Phase 5
#
# First, A Glimpse Post-Capstone: Tech Prep Course!
#
#  - Tech Prep
#
# Welcome
#
#  - Capstone Timeline (Live)
#  - Capstone Project Description
#
# Resources
#
#  - Capstone Examples
#  - Choosing a Capstone Topic and Dataset
#  - Reproducibility
#
# Flex Capstone Preparation
#
#  - Capstone Brainstorming
#  - Capstone Brainstorming Survey
#  - Capstone Project Proposal
#  - Capstone Project Proposal Example 1 .pdf
#  - Capstone Project Proposal Example 2.pdf
#
# Live Capstone Preparation
#
#  - Capstone Timeline (Live)
#  - Capstone Brainstorming
#  - Capstone Brainstorming Survey
#  - Capstone Project Proposal
#  - Capstone Project Proposal Example 1 .pdf
#  - Capstone Project Proposal Example 2.pdf
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-027299399507> in <module>
#      25         all_text = all_text + "</ul>"
#      26     all_text = all_text + "</div>"
# ---> 27 save_html_file("DS_Links.html")
#
# NameError: name 'save_html_file' is not defined

# %%
def save_html_file(file_path):
    all_text_begin = '''
    <meta name="viewport" content="width=device-width, initial-scale=1">
    <style>
    .collapsible {
      background-color: #777;
      color: white;
      cursor: pointer;
      padding: 3px;
      width: 100%;
      border: none;
      text-align: left;
      outline: none;
      font-size: 15px;
    }

    .active, .collapsible:hover {
      background-color: #555;
    }

    .content {
      padding: 0 18px;
      display: none;
      overflow: hidden;
      background-color: #f1f1f1;
    }
    </style>
    </head>
    <body>
    '''

    all_text_end = '''
    <script>
    var coll = document.getElementsByClassName("collapsible");
    var i;

    for (i = 0; i < coll.length; i++) {
      coll[i].addEventListener("click", function() {
        this.classList.toggle("active");
        var content = this.nextElementSibling;
        if (content.style.display === "block") {
          content.style.display = "none";
        } else {
          content.style.display = "block";
        }
      });
    }
    </script>

    </body>
    </html>

    '''

    output_file_obj = open(file_path, mode='w')
    output_file_obj.write(all_text_begin + all_text + all_text_end)
    output_file_obj.close()

# %%
save_html_file("pre-work.html")
